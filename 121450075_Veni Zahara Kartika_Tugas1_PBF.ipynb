# %% [markdown]
# # Tugas Pemrograman Berbasis Fungsi 1

# %% [markdown]
# ### Nama: Veni Zahara Kartika
# ### NIM: 121450075

# %% [markdown]
# ## Nomor 1

# %% [markdown]
# Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan object oriented (minimal 3) !

# %% [markdown]
# ### Jawab:

# %% [markdown]
# ![Screenshot_20230205_010427.png](attachment:Screenshot_20230205_010427.png)

# %% [markdown]
# ## Nomor 2

# %% [markdown]
# Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma object oriented dibandingkan dengan functional (minimal 3) !

# %% [markdown]
# ### Jawab:

# %% [markdown]
# ![Screenshot_20230205_010443.png](attachment:Screenshot_20230205_010443.png)

# %% [markdown]
# ## Nomor 3

# %% [markdown]
# Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan functional (minimal 3) !

# %% [markdown]
# ### Jawab:

# %% [markdown]
# ![Screenshot_20230205_010456.png](attachment:Screenshot_20230205_010456.png)

# %% [markdown]
# ## Nomor 4

# %% [markdown]
# Apa yang dimaksud dengan pure functional programming language?

# %% [markdown]
# ### Jawab:

# %% [markdown]
# Pure functional programming language adalah paradigma pemrograman yang membangun struktur dan elemen program komputer melalui komputasi yang berasal dari fungsi-fungsi matematika sebagai dasar solusi dari suatu persoalan.

# %% [markdown]
# ## Nomor 5

# %% [markdown]
# Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah yang termasuk pure functional programming language?

# %% [markdown]
# ### Jawab:

# %% [markdown]
# Pada slide 14 yang termasuk pure functional programming language adalah Haskell dan lisp

# %% [markdown]
# ## Nomor 6

# %% [markdown]
# Membuat program Simple Password encryption, dengan ketentuan
# 1. Input password bertipe string dengan batasan panjang password
# 100 karakter
# 2. Setiap karakter dari string tersebut diubah menjadi ASCII value
# 3. Kemudian setiap ASCII value tersebut dikembangkan menjadi 3
# value dengan dilakukan operasi berikut:
# 1. Value pertama dibagi dengan integer 26 kemudian
# dibulatkan dan dijumlahkan dengan 80 kemudian diubah
# kembali menjadi karakter
# 2. Value kedua dihitung sisa bagi dengan 26 kemudian
# dijumlahkan dengan 80 kemudian diubah kembali menjadi
# karakter
# 3. Value ketiga adalah karakter ‘+’ jika value pertama lebih
# besar dari value kedua, atau value ketiga adalah karakter ‘-’
# jika value pertama tidak lebih besar dari value kedua
# 4. Deretkan value pertama, kedua dan ketiga untuk setiap karakter
# dalam password tersebut sehingga didapatkan password dalam
# bentuk baru

# %% [markdown]
# ### Jawab:

# %%
def encryption(pw):
    if len(pw)>100:
        return "Batas pw 100 karakter"
    
    encryption_pw=""
    for char in pw:
        ascii_value = ord(char)
        value_pertama = round((ascii_value // 26)) + 80
        value_kedua = (ascii_value % 26) + 80
        value_ketiga = '+' if value_pertama > value_kedua else '-'
        encryption_pw += chr(value_pertama) + chr(value_kedua) + value_ketiga
    return encryption_pw

# %%
password = input("Masukkan password: ")
encryption_pw = encryption(password)
print("Password encryption:", encryption_pw)
# Out:
# Masukkan password: berhasil
# Password encryption: Sd-Sg-TZ-TP+Sc-T[-TQ+TT-
